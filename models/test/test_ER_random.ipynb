# %%
import os
import sys
sys.path.append(r"../")
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from connect.ER_random import *

# %%
Num = int(100)
conn = create_ER_p(Num, 0.3)
print(conn.sum()/Num)
# Out:
# 29.8

# %%
conn = create_ER_M(Num, 200)
print(conn.sum()/Num)
# Out:
# 2.0

# %%
Num = int(100)
p = 0.1
M = 400
directed=True
rn = Erdos_Renyi(Num, M=M)  # 
conn = rn.creat_ER_network()
print(conn.sum()/Num)
# Out:
# 8.0

# %%
rn.degree_distribution(True)
# Out:
# {2: 0.01,
#  3: 0.02,
#  4: 0.04,
#  5: 0.09,
#  6: 0.11,
#  7: 0.16,
#  8: 0.2,
#  9: 0.14,
#  10: 0.05,
#  11: 0.09,
#  12: 0.04,
#  13: 0.02,
#  14: 0.02,
#  16: 0.01}

# %%
rn.average_path_length()
# rn.clustering_coefficient()
# rn.average_degree()
rn.draw_network()

# %%
Num = int(100)
p = 0.1
M = 400
directed=True
rn = DiErdos_Renyi(Num, M=M)  # 
conn = rn.creat_ER_network()
print(conn.sum()/Num)
# Out:
# 4.0

# %%
rn.degree_distribution(True)
# Out:
# {3: 0.07,
#  4: 0.04,
#  5: 0.06,
#  6: 0.08,
#  7: 0.17,
#  8: 0.24,
#  9: 0.1,
#  10: 0.08,
#  11: 0.04,
#  12: 0.04,
#  13: 0.03,
#  14: 0.03,
#  15: 0.01,
#  16: 0.01}

# %%
rn.average_path_length()
rn.clustering_coefficient()
rn.average_degree(degree_type="out")
rn.draw_network()
