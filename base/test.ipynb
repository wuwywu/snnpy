# %%
import seaborn as sns
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import proj3d
import numpy as np
import pandas as pd
import torch
import torch.nn as nn

# %%
torch.rand((10,4)).max()
# Out:
# tensor(0.9741)

# %%
a = torch.tensor([1,2,3]).reshape(1,-1) #[1,3]
b = torch.tensor([1,2,3]).reshape(1,-1) #[1,3]
torch.cat([a, b], dim=0)
# Out:
# tensor([[1, 2, 3],
#         [1, 2, 3]])

# %%
F(a).shape
# Out:
# torch.Size([3, 36, 5])

# %%
file1 = r"./datas/save2.csv"
df1 = pd.read_csv(file1)
data1 = df1.values
file2 = r"./datas/save4_labels.csv"
df_labels = pd.read_csv(file2)
label = df_labels.values.flatten()

# %%
data1
# Out:
# array([[0.32375   , 0.42249998, 0.24499999, ..., 0.775     , 0.24749999,
#         0.        ],
#        [0.0875    , 0.20625   , 0.15124999, ..., 0.        , 0.        ,
#         0.        ],
#        [0.505     , 0.345     , 0.01125   , ..., 0.35125   , 0.        ,
#         0.01125   ],
#        ...,
#        [0.18124999, 0.085     , 0.075     , ..., 0.96625   , 0.2325    ,
#         0.        ],
#        [0.08875   , 0.        , 0.        , ..., 0.        , 0.3075    ,
#         0.        ],
#        [0.00625   , 0.2525    , 0.22375   , ..., 0.        , 0.0025    ,
#         0.09874999]])

# %%
plot_tsne2d(data1, label)
# plt.legend()

# %%
np.array(sns.color_palette("hls", 10)) # 获取不同类别的颜色（三原色）
# Out:
# array([[0.86  , 0.3712, 0.34  ],
#        [0.86  , 0.6832, 0.34  ],
#        [0.7248, 0.86  , 0.34  ],
#        [0.4128, 0.86  , 0.34  ],
#        [0.34  , 0.86  , 0.5792],
#        [0.34  , 0.8288, 0.86  ],
#        [0.34  , 0.5168, 0.86  ],
#        [0.4752, 0.34  , 0.86  ],
#        [0.7872, 0.34  , 0.86  ],
#        [0.86  , 0.34  , 0.6208]])
